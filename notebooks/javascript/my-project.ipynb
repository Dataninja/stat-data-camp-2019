// %%
var d3 = require('d3')
console.log(d3)
// Out:
// { bisect: [Getter],
//   bisectRight: [Getter],
//   bisectLeft: [Getter],
//   ascending: [Getter],
//   bisector: [Getter],
//   cross: [Getter],
//   descending: [Getter],
//   deviation: [Getter],
//   extent: [Getter],
//   histogram: [Getter],
//   thresholdFreedmanDiaconis: [Getter],
//   thresholdScott: [Getter],
//   thresholdSturges: [Getter],
//   max: [Getter],
//   mean: [Getter],
//   median: [Getter],
//   merge: [Getter],
//   min: [Getter],
//   pairs: [Getter],
//   permute: [Getter],
//   quantile: [Getter],
//   range: [Getter],
//   scan: [Getter],
//   shuffle: [Getter],
//   sum: [Getter],
//   ticks: [Getter],
//   tickIncrement: [Getter],
//   tickStep: [Getter],
//   transpose: [Getter],
//   variance: [Getter],
//   zip: [Getter],
//   axisTop: [Getter],
//   axisRight: [Getter],
//   axisBottom: [Getter],
//   axisLeft: [Getter],
//   brush: [Getter],
//   brushSelection: [Getter],
//   brushX: [Getter],
//   brushY: [Getter],
//   chord: [Getter],
// ...
